# %%
#importe das biblicotes necessarias 
import pandas as pd  # principal
import pandera as pa #construr o schema para validação
import  matplotlib.pyplot as plt #demostrações graficas dos dados

# %%
df = pd.read_csv("dadosCiclo08.csv",encoding="UTF-8",sep="\t")#importanto os dados

# %%
df
# Out:
#      PedNumero  PedCiclo  PedCliente PedUF                  PedData  PedValor  \
# 0     94359749    202008     4923291    MG  2020-06-06 00:00:00.000   1933.06
# 1     94359749    202008     4923291    MG  2020-06-06 00:00:00.000   1933.06
# 2     94359749    202008     4923291    MG  2020-06-06 00:00:00.000   1933.06
# 3     94359749    202008     4923291    MG  2020-06-06 00:00:00.000   1933.06
# 4     94359749    202008     4923291    MG  2020-06-06 00:00:00.000   1933.06
# ..         ...       ...         ...   ...                      ...       ...
# 208   94819448    202008     4950462    DF  2020-08-31 00:00:00.000    756.00
# 209   94819448    202008     4950462    DF  2020-08-31 00:00:00.000    756.00
# 210   94819448    202008     4950462    DF  2020-08-31 00:00:00.000    756.00
# 211   94825187    202008     4906745    TO  2020-08-31 00:00:00.000    897.30
# 212   94825187    202008     4906745    TO  2020-08-31 00:00:00.000    897.30
#
# ...

# %%
#verificar quantos itens Nas tem, no caso PedPresente só tem valores Nas
df.isna().sum()
# Out:
# PedNumero      0
# PedCiclo       0
# PedCliente     0
# PedUF          0
# PedData        0
# PedValor       0
# PedDesconto    0
# PedValFrete    0
# PedOrigem      0
# PedDtLib       0
# PedDtInc       0
# ItPProduto     0
# ItPQtde        0
# ItPrecoComp    0
# ProdDescr      0
# dtype: int64

# %%
#Excluir coluna PedPresente já que não tem dados
df.drop(["PedPresente"], axis=1,inplace=True)
