# %%
import pandas as pd #importar pandas
import numpy as np

# %%
df = pd.read_csv("ocorrencia.csv",encoding='latin-1',sep=';',parse_dates=['ocorrencia_dia'],dayfirst=True)#le arquivo CSV mudar o encoding para latin e o separador para ; e converte campos para data e colocando o dia primeiro.
df.head()#imprimir as 5 primeiras linhas
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.loc[1,'ocorrencia_cidade']#busca uma determinada linha/coluna
# Out:
# 'BELÉM'

# %%
df.loc[1]#busca a linha completa
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.loc[1:3]#busca range de linhas
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df.loc[{10,40}]#busca duas linhas tipo lista.
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 40              39158               39158                INCIDENTE
# 10              39789               39789                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 40             BELÉM            PA                 ****     2010-01-28
# 10  SÃO PEDRO DO SUL            RS                          2010-01-10
#
#    ocorrencia_hora  total_recomendacoes
# 40        16:00:00                    0
# 10        21:30:00                    0

# %%
df.loc[:,'ocorrencia_cidade']#buscar uma coluna completa
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
df.codigo_ocorrencia.is_unique#verificar se determinada coluna é unica tipo CPF
# Out:
# True

# %%
df.set_index('codigo_ocorrencia',inplace=True) #mudar index tipo chave primaria usando o codigo da ocorrecia que é um valor unico tipo CPF

# %%
df.loc[40324]#busca a linha inteira pelo novo indice escolhido acima.
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %%
df.reset_index(drop=True,inplace=True)#excluir o index atual ou seja voltar para um index sequencial

# %%
df.loc[0,'ocorrencia_aerodromo']=''#passar os itens **** para vazio já que esse **** no CSV signifca que não tem o dado.

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
df.loc[1]=20#altera toda a linha 1 para 20

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 ****  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                   20
# 2                    0
# ...

# %%
df.loc[:,'total_recomendacoes']= 10 #altera todas as linhas de determinada coluna.

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 ****  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes
# 0                   10
# 1                   10
# 2                   10
# ...

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf #cria uma coluna e copia para  bkp que recebe os dados de ocorrencia_uf em outra coluna

# %%
df['novo coluna'] = 'pao de queijo'

# %%
df.loc[df.ocorrencia_uf=='SP',['ocorrencia_classificacao']]='GRAVE' #preencher o dado usando um filtro

# %%
df.loc[df.ocorrencia_uf=='SP']#filtra a busca para Uf de SP`apenas
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 11                 40069                    GRAVE          SÃO PAULO
# 16                 39809                    GRAVE          SÃO PAULO
# 18                 39828                    GRAVE             SANTOS
# 26                 39847                    GRAVE           SOROCABA
# 27                 39768                    GRAVE           CAMPINAS
# ...                  ...                      ...                ...
# 6084               80234                    GRAVE          SÃO PAULO
# 6085               80208                    GRAVE          SÃO PAULO
# 6104               80238                    GRAVE        VOTUPORANGA
# 6108               80244                    GRAVE  BRAGANÇA PAULISTA
# 6113               80259                    GRAVE           CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [raw]
# dados que vamos limpar e suas colunas
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL

# %%
df.loc[df.ocorrencia_aerodromo=='****',['ocorrencia_aerodromo']]=pd.NA #substuir dados **** por NA ou seja não existeste pandas

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.replace(['**','###!','####','*****','****','NULL'], pd.NA , inplace=True)#atualizar varios dados por NA ao mesmpo tempo

# %%
df.loc[df.ocorrencia_hora=='S/H']
# Out:
# Empty DataFrame
# Columns: [codigo_ocorrencia, codigo_ocorrencia2, ocorrencia_classificacao, ocorrencia_cidade, ocorrencia_uf, ocorrencia_aerodromo, ocorrencia_dia, ocorrencia_hora, total_recomendacoes]
# Index: []

# %%
df.isna().sum()#somar numero de dados por coluna que são NA
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2455
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.fillna(10)#colocar dados em todos os NAs
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.fillna(value={'ocorrencia_hora':'S/H'},inplace=True) #alterar NA para valor com filtro

# %%
df.replace(['S/H'], pd.NA , inplace=True)#atualizar varios dados por NA ao mesmpo tempo
# Out:
# C:\Users\jo_co\anaconda3\lib\site-packages\pandas\core\missing.py:47: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.drop(['total_recomendacoes_bkp'])#excluir uma linha
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0        12:00:00                    0                        0
# ...

# %%
df.drop(['total_recomendacoes_bkp'],axis=1,inplace=True)#excluir uma coluna

# %%
df.dropna()#excluir TODOS os valores não informados e exclui A LINHA toda
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 4                 40324               40324                INCIDENTE
# 6                 40215               40215                INCIDENTE
# 8                 39156               39156          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6108              80244               80244                INCIDENTE
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dropna(subset=['ocorrencia_uf'])#excluir dados NA de uma coluna.
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.drop_duplicates(inplace=True)#tirar valores duplicados

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6109            RECIFE            PE                 SBRF     2021-08-15
# 6110       PORTO VELHO            RO                 SBPV     2021-08-16
# 6111             BELÉM            PA                 SBBE     2021-08-17
# 6112        DOM AQUINO            MT                 <NA>     2021-08-18
# 6113          CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 6109        15:05:00                    0
# ...
